# %% [markdown]
# <a href="https://colab.research.google.com/github/gimyeonjik/2025-AIX-DL-PROJECT/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 45.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

res = YOLO("yolov8n.pt")("cat.jpg")
cv2_imshow(res[0].plot())
# Out:
# ...
#
# image 1/1 /content/cat.jpg: 512x640 1 cat, 441.1ms
# Speed: 18.8ms preprocess, 441.1ms inference, 43.8ms postprocess per image at shape (1, 3, 512, 640)
# <PIL.Image.Image image mode=RGB size=1000x779>
